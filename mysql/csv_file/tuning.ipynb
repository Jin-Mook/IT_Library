# %%
import pandas as pd
df = pd.read_csv('./최종_책_데이터.csv', encoding='utf8')
df.head(5)
# Out:
#    id                book_title  book_category  \
# 0   1                   유니티 교과서              1
# 1   2                이득우의 게임 수학              1
# 2   3      로블록스 게임 제작 무작정 따라하기               1
# 3   4     레트로의 유니티 게임 프로그래밍 에센스              1
# 4   5  유튜버 옐롯과 함께하는 로블록스 게임 만들기              1
#
#                                   book_image book_writer book_publisher  \
# 0  http://image.yes24.com/goods/107079711/XL    기타무라 마나미             길벗
# 1  http://image.yes24.com/goods/107025224/XL         이득우             책만
# 2  http://image.yes24.com/goods/101924438/XL         서종원             길벗
# 3  http://image.yes24.com/goods/106537338/XL         이제민          한빛미디어
# 4  http://image.yes24.com/goods/107888693/XL          옐롯           위키북스
#
#   publish_date                                          book_info
# 0   2022-02-14  <b>검증된 베스트셀러 [유니티 교과서] <br>\r\n유니티 2021 버전에 맞춰...
# 1   2022-02-22  <b>39가지 실시간 렌더링 게임 프로그래밍 실습 예제를 하나씩 따라 해보며 <br...
# ...

# %%
df2 = df.reindex(columns=['id', 'book_title', 'book_image', 'book_writer', 'book_publisher', 'publish_date', 'book_category', 'book_info'])

df2['book_rating'] = 0
df2['book_like_count'] = 0
df2['comments_count'] = 0
df2.tail(5)
# Out:
#           id                 book_title  \
# 40934  40935                   빅데이터 입문
# 40935  40936               리눅스 커널 프로그래밍
# 40936  40937                  사물인터넷의 충격
# 40937  40938        SystemC를 이용한 시스템 설계
# 40938  40939  Microsofr SQL Server 2000
#
#                                               book_image  \
# 40934  http://image.yes24.com/momo/TopCate562/MidCate...
# 40935  http://image.yes24.com/momo/TopCate553/MidCate...
# 40936  http://image.yes24.com/momo/TopCate551/MidCate...
# 40937  http://image.yes24.com/momo/TopCate07/MidCate0...
# 40938  http://image.yes24.com/momo/TopCate04/MidCate0...
#
#                                  book_writer book_publisher publish_date  \
# 40934                                    전도홍            정익사   2015-06-30
# 40935                                    한동훈          한빛미디어   2007-01-02
# 40936                  Cisco 시스템즈 IoT인큐베이션 랩          인포더북스   2015-08-14
# 40937          Thorsten Grotker 외 공저 / 국일호 역         에이콘출판사   2003-03-01
# ...

# %%
df2.to_csv('final_data.csv', index=0, encoding='utf8')
